# %% [markdown]
# # Fine-tuning on Pre-trained Model with Batch Integration
# In this tutorial, we demonstrate how to fine-tune a pre-trained model on a new dataset for the batch integration task. We use the PBMC 10K dataset as an example and fine-tune on the pre-trained whole-body model.
#
# We summarize the fine-tuning pipeline in the following steps, which can be used as a general recipe for finetuning on integration tasks and beyond:
#
#      1. Specify hyper-parameter setup for integration task
#
#      2. Load and pre-process data
#
#      3. Load the pre-trained scGPT model
#
#      4. Finetune scGPT with task-specific objectives
#
#      5. Evaluate fine-tuned scGPT

# %%
import copy
import gc
import json
import os
from pathlib import Path
import sys
import time
import traceback
from typing import List, Tuple, Dict, Union, Optional
import warnings

import torch
from anndata import AnnData
import scanpy as sc
import scvi
import numpy as np
import wandb
from scipy.sparse import issparse
import matplotlib.pyplot as plt
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torchtext.vocab import Vocab
from torchtext._torchtext import (
    Vocab as VocabPybind,
)


sys.path.insert(0, "../")
import scgpt as scg
from scgpt.model import TransformerModel, AdversarialDiscriminator
from scgpt.tokenizer import tokenize_and_pad_batch, random_mask_value
from scgpt.tokenizer.gene_tokenizer import GeneVocab
from scgpt.loss import (
    masked_mse_loss,
    masked_relative_error,
    criterion_neg_log_bernoulli,
)
from scgpt.preprocess import Preprocessor
from scgpt import SubsetsBatchSampler
from scgpt.utils import set_seed, eval_scib_metrics, load_pretrained

sc.set_figure_params(figsize=(4, 4))
os.environ["KMP_WARNINGS"] = "off"
warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /home/whytin/Research/Project/scGPT/tutorials/../scgpt/model/model.py:21: UserWarning: flash_attn is not installed
#   warnings.warn("flash_attn is not installed")
# /home/whytin/Research/Project/scGPT/tutorials/../scgpt/model/multiomic_model.py:19: UserWarning: flash_attn is not installed
#   warnings.warn("flash_attn is not installed")

# %% [markdown]
# ## Step1: Specify hyper-parameter setup for integration task
# Here we provide some hyper-parameter recommendations here for the integration task. Note that the PBMC 10K dataset contains multiple batches to be integrated. Therefore, in addition to the default gene modelling objectives, we also turn on ESC, DAR and DSBN objectives specifically to faciliate batch integration.

# %%
hyperparameter_defaults = dict(
    seed=42,
    dataset_name="Breast_HD", # Dataset name
    do_train=True, # Flag to indicate whether to do update model parameters during training
    load_model="../save/scGPT_human", # Path to pre-trained model
    GEPC=True,  # Gene expression modelling for cell objective
    ecs_thres=0.8,  # Elastic cell similarity objective, 0.0 to 1.0, 0.0 to disable
    dab_weight=1.0, # DAR objective weight for batch correction
    mask_ratio=0.4, # Default mask ratio
    epochs=5, # Default number of epochs for fine-tuning
    n_bins=51, # Default number of bins for value binning in data pre-processing
    lr=1e-4, # Default learning rate for fine-tuning
    #batch_size=64, # Default batch size for fine-tuning
    batch_size=16, # Default batch size for fine-tuning
    layer_size=128,
    nlayers=4,
    nhead=4, # if load model, batch_size, layer_size, nlayers, nhead will be ignored
    dropout=0.2, # Default dropout rate during model fine-tuning
    schedule_ratio=0.9,  # Default rate for learning rate decay
    save_eval_interval=1, # Default model evaluation interval
    log_interval=100, # Default log interval
    fast_transformer=True, # Default setting
    pre_norm=False, # Default setting
    amp=True,  # # Default setting: Automatic Mixed Precision
)
run = wandb.init(
    config=hyperparameter_defaults,
    project="scGPT",
    reinit=True,
    settings=wandb.Settings(start_method="fork"),
)
config = wandb.config
print(config)

set_seed(config.seed)
# Out:
# wandb: Network error (InvalidSchema), entering retry loop.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Network error (InvalidSchema), entering retry loop.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# creating run (0.5s)
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/whytin/Research/Project/scGPT/tutorials/wandb/run-20250517_085543-lldl0r32</code>
# Syncing run <strong><a href='https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT/runs/lldl0r32' target="_blank">good-waterfall-20</a></strong> to <a href='https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT' target="_blank">https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT</a>
#  View run at <a href='https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT/runs/lldl0r32' target="_blank">https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT/runs/lldl0r32</a>
# {'seed': 42, 'dataset_name': 'Breast_HD', 'do_train': True, 'load_model': '../save/scGPT_human', 'GEPC': True, 'ecs_thres': 0.8, 'dab_weight': 1.0, 'mask_ratio': 0.4, 'epochs': 5, 'n_bins': 51, 'lr': 0.0001, 'batch_size': 16, 'layer_size': 128, 'nlayers': 4, 'nhead': 4, 'dropout': 0.2, 'schedule_ratio': 0.9, 'save_eval_interval': 1, 'log_interval': 100, 'fast_transformer': True, 'pre_norm': False, 'amp': True}

# %%
# settings for input and preprocessing
pad_token = "<pad>"
special_tokens = [pad_token, "<cls>", "<eoc>"]
mask_ratio = config.mask_ratio
mask_value = -1
pad_value = -2
n_input_bins = config.n_bins

n_hvg = 1200  # number of highly variable genes
max_seq_len = n_hvg + 1
per_seq_batch_sample = True
DSBN = True  # Domain-spec batchnorm
explicit_zero_prob = True  # whether explicit bernoulli for zeros

# %%
dataset_name = config.dataset_name
save_dir = Path(f"./save/dev_{dataset_name}-{time.strftime('%b%d-%H-%M')}/")
save_dir.mkdir(parents=True, exist_ok=True)
print(f"save to {save_dir}")
logger = scg.logger
scg.utils.add_file_handler(logger, save_dir / "run.log")
# Out:
# save to save/dev_Breast_HD-May17-00-58

# %% [markdown]
# ## Step 2: Load and pre-process data

# %% [markdown]
# ### 2.1 Load the PBMC 10K data

# %%
if dataset_name == "PBMC_10K":
    adata = scvi.data.pbmc_dataset()  # 11990 × 3346
    ori_batch_col = "batch"
    adata.obs["celltype"] = adata.obs["str_labels"].astype("category")
    adata.var = adata.var.set_index("gene_symbols")
    data_is_raw = True

# make the batch category column
adata.obs["str_batch"] = adata.obs[ori_batch_col].astype(str)
batch_id_labels = adata.obs["str_batch"].astype("category").cat.codes.values
adata.obs["batch_id"] = batch_id_labels
adata.var["gene_name"] = adata.var.index.tolist()
# Out:
# INFO     File data/gene_info_pbmc.csv already downloaded
# INFO     File data/pbmc_metadata.pickle already downloaded
# INFO     File data/pbmc8k/filtered_gene_bc_matrices.tar.gz already downloaded
# INFO     Extracting tar file
# INFO     Removing extracted data at data/pbmc8k/filtered_gene_bc_matrices
# INFO     File data/pbmc4k/filtered_gene_bc_matrices.tar.gz already downloaded
# INFO     Extracting tar file
# INFO     Removing extracted data at data/pbmc4k/filtered_gene_bc_matrices

# %%
adata = sc.read_h5ad('/home/whytin/Research/Project/scGPT/tutorials/data/breast_combined_adata.h5ad')

# %%
adata.var['gene_name'] = adata.var['gene_id']
adata.obs["str_batch"] = adata.obs['batch_id'].astype(str)
adata.obs['batch_id']=adata.obs['str_batch'].astype("category").cat.codes.values

# %%
data_is_raw = False

# %% [markdown]
# ### 2.2 Cross-check gene set with the pre-trained model
# Note that we retain the common gene set between the data and the pre-trained model for further fine-tuning.

# %%
if config.load_model is not None:
    model_dir = Path(config.load_model)
    model_config_file = model_dir / "args.json"
    model_file = model_dir / "best_model.pt"
    vocab_file = model_dir / "vocab.json"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    adata = adata[:, adata.var["id_in_vocab"] >= 0]
    
    # model
    with open(model_config_file, "r") as f:
        model_configs = json.load(f)
    logger.info(
        f"Resume model from {model_file}, the model args will be overriden by the "
        f"config {model_config_file}."
    )
    embsize = model_configs["embsize"]
    nhead = model_configs["nheads"]
    d_hid = model_configs["d_hid"]
    nlayers = model_configs["nlayers"]
    n_layers_cls = model_configs["n_layers_cls"]
else:
    embsize = config.layer_size 
    nhead = config.nhead
    nlayers = config.nlayers  
    d_hid = config.layer_size
# Out:
# scGPT - INFO - match 14626/14637 genes in vocabulary of size 60697.
# scGPT - INFO - Resume model from ../save/scGPT_human/best_model.pt, the model args will be overriden by the config ../save/scGPT_human/args.json.

# %% [markdown]
# ### 2.3 Pre-process the data
# We follow the standardized pipline of depth normalization, log normalization, and highly vairable gene (HVG) selection for data pre-processing. We further introduced value binning to obtain the relative expressions of each HVG.

# %%
# set up the preprocessor, use the args to config the workflow
preprocessor = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=3,  # step 1
    filter_cell_by_counts=False,  # step 2
    normalize_total=1e4,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=data_is_raw,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=n_hvg,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor="seurat_v3" if data_is_raw else "cell_ranger",
    binning=config.n_bins,  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor(adata, batch_key="str_batch" if dataset_name != "heart_cell" else None)
# Out:
# scGPT - INFO - Filtering genes by counts ...
# scGPT - INFO - Normalizing total counts ...
# scGPT - INFO - Subsetting highly variable genes ...
# scGPT - INFO - Binning data ...
# scGPT - WARNING - The input data contains all zero rows. Please make sure this is expected. You can use the `filter_cell_by_counts` arg to filter out all zero rows.
# scGPT - WARNING - The input data contains all zero rows. Please make sure this is expected. You can use the `filter_cell_by_counts` arg to filter out all zero rows.
# scGPT - WARNING - The input data contains all zero rows. Please make sure this is expected. You can use the `filter_cell_by_counts` arg to filter out all zero rows.
# scGPT - WARNING - The input data contains all zero rows. Please make sure this is expected. You can use the `filter_cell_by_counts` arg to filter out all zero rows.
# scGPT - WARNING - The input data contains all zero rows. Please make sure this is expected. You can use the `filter_cell_by_counts` arg to filter out all zero rows.

# %%
if per_seq_batch_sample:
    # sort the adata by batch_id in advance
    adata_sorted = adata[adata.obs["batch_id"].argsort()].copy()

# %% [markdown]
# ### 2.4 Tokenize the input data for model fine-tuning

# %%
input_layer_key = "X_binned"
all_counts = (
    adata.layers[input_layer_key].toarray()
    if issparse(adata.layers[input_layer_key])
    else adata.layers[input_layer_key]
)
genes = adata.var["gene_name"].tolist()

celltypes_labels = adata.obs["celltype"].tolist()  # make sure count from 0
num_types = len(set(celltypes_labels))
celltypes_labels = np.array(celltypes_labels)

batch_ids = adata.obs["batch_id"].tolist()
num_batch_types = len(set(batch_ids))
batch_ids = np.array(batch_ids)

(
    train_data,
    valid_data,
    train_celltype_labels,
    valid_celltype_labels,
    train_batch_labels,
    valid_batch_labels,
) = train_test_split(
    all_counts, celltypes_labels, batch_ids, test_size=0.1, shuffle=True
)

# %%
if config.load_model is None:
    vocab = Vocab(
        VocabPybind(genes + special_tokens, None)
    )  # bidirectional lookup [gene <-> int]
vocab.set_default_index(vocab["<pad>"])
gene_ids = np.array(vocab(genes), dtype=int)

# %%
tokenized_train = tokenize_and_pad_batch(
    train_data,
    gene_ids,
    max_len=max_seq_len,
    vocab=vocab,
    pad_token=pad_token,
    pad_value=pad_value,
    append_cls=True,  # append <cls> token at the beginning
    include_zero_gene=True,
)
tokenized_valid = tokenize_and_pad_batch(
    valid_data,
    gene_ids,
    max_len=max_seq_len,
    vocab=vocab,
    pad_token=pad_token,
    pad_value=pad_value,
    append_cls=True,
    include_zero_gene=True,
)
logger.info(
    f"train set number of samples: {tokenized_train['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_train['genes'].shape[1]}"
)
logger.info(
    f"valid set number of samples: {tokenized_valid['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_valid['genes'].shape[1]}"
)
# Out:
# scGPT - INFO - train set number of samples: 310202,
# 	 feature length: 1201
# scGPT - INFO - valid set number of samples: 34467,
# 	 feature length: 1201

# %%
def prepare_data(sort_seq_batch=False) -> Tuple[Dict[str, torch.Tensor]]:
    masked_values_train = random_mask_value(
        tokenized_train["values"],
        mask_ratio=mask_ratio,
        mask_value=mask_value,
        pad_value=pad_value,
    )
    masked_values_valid = random_mask_value(
        tokenized_valid["values"],
        mask_ratio=mask_ratio,
        mask_value=mask_value,
        pad_value=pad_value,
    )
    print(
        f"random masking at epoch {epoch:3d}, ratio of masked values in train: ",
        f"{(masked_values_train == mask_value).sum() / (masked_values_train - pad_value).count_nonzero():.4f}",
    )

    input_gene_ids_train, input_gene_ids_valid = (
        tokenized_train["genes"],
        tokenized_valid["genes"],
    )
    input_values_train, input_values_valid = masked_values_train, masked_values_valid
    target_values_train, target_values_valid = (
        tokenized_train["values"],
        tokenized_valid["values"],
    )

    tensor_batch_labels_train = torch.from_numpy(train_batch_labels).long()
    tensor_batch_labels_valid = torch.from_numpy(valid_batch_labels).long()

    if sort_seq_batch:
        train_sort_ids = np.argsort(train_batch_labels)
        input_gene_ids_train = input_gene_ids_train[train_sort_ids]
        input_values_train = input_values_train[train_sort_ids]
        target_values_train = target_values_train[train_sort_ids]
        tensor_batch_labels_train = tensor_batch_labels_train[train_sort_ids]

        valid_sort_ids = np.argsort(valid_batch_labels)
        input_gene_ids_valid = input_gene_ids_valid[valid_sort_ids]
        input_values_valid = input_values_valid[valid_sort_ids]
        target_values_valid = target_values_valid[valid_sort_ids]
        tensor_batch_labels_valid = tensor_batch_labels_valid[valid_sort_ids]

    train_data_pt = {
        "gene_ids": input_gene_ids_train,
        "values": input_values_train,
        "target_values": target_values_train,
        "batch_labels": tensor_batch_labels_train,
    }
    valid_data_pt = {
        "gene_ids": input_gene_ids_valid,
        "values": input_values_valid,
        "target_values": target_values_valid,
        "batch_labels": tensor_batch_labels_valid,
    }

    return train_data_pt, valid_data_pt


# dataset
class SeqDataset(Dataset):
    def __init__(self, data: Dict[str, torch.Tensor]):
        self.data = data

    def __len__(self):
        return self.data["gene_ids"].shape[0]

    def __getitem__(self, idx):
        return {k: v[idx] for k, v in self.data.items()}


# data_loader
def prepare_dataloader(
    data_pt: Dict[str, torch.Tensor],
    batch_size: int,
    shuffle: bool = False,
    intra_domain_shuffle: bool = False,
    drop_last: bool = False,
    num_workers: int = 0,
) -> DataLoader:
    dataset = SeqDataset(data_pt)

    if per_seq_batch_sample:
        # find the indices of samples in each seq batch
        subsets = []
        batch_labels_array = data_pt["batch_labels"].numpy()
        for batch_label in np.unique(batch_labels_array):
            batch_indices = np.where(batch_labels_array == batch_label)[0].tolist()
            subsets.append(batch_indices)
        data_loader = DataLoader(
            dataset=dataset,
            batch_sampler=SubsetsBatchSampler(
                subsets,
                batch_size,
                intra_subset_shuffle=intra_domain_shuffle,
                inter_subset_shuffle=shuffle,
                drop_last=drop_last,
            ),
            num_workers=num_workers,
            pin_memory=True,
        )
        return data_loader

    data_loader = DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,
    )
    return data_loader

# %% [markdown]
#  ## Step 3: Load the pre-trained scGPT model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

ntokens = len(vocab)  # size of vocabulary
model = TransformerModel(
    ntokens,
    embsize,
    nhead,
    d_hid,
    nlayers,
    vocab=vocab,
    dropout=config.dropout,
    pad_token=pad_token,
    pad_value=pad_value,
    do_mvc=config.GEPC,
    do_dab=True,
    use_batch_labels=True,
    num_batch_labels=num_batch_types,
    domain_spec_batchnorm=DSBN,
    n_input_bins=n_input_bins,
    ecs_threshold=config.ecs_thres,
    explicit_zero_prob=explicit_zero_prob,
    use_fast_transformer=config.fast_transformer,
    pre_norm=config.pre_norm,
)
if config.load_model is not None:
    load_pretrained(model, torch.load(model_file), verbose=False)

model.to(device)
wandb.watch(model)
# Out:
# Use domain specific batchnorm with affine=False

# %%
criterion = masked_mse_loss
criterion_dab = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=config.lr, eps=1e-4 if config.amp else 1e-8
)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=config.schedule_ratio)
scaler = torch.cuda.amp.GradScaler(enabled=config.amp)

# %%
def train(model: nn.Module, loader: DataLoader) -> None:
    """
    Train the model for one epoch.
    """
    model.train()
    total_loss, total_mse, total_gepc = 0.0, 0.0, 0.0
    total_error = 0.0
    log_interval = config.log_interval
    start_time = time.time()

    num_batches = len(loader)
    for batch, batch_data in enumerate(loader):
        input_gene_ids = batch_data["gene_ids"].to(device)
        input_values = batch_data["values"].to(device)
        target_values = batch_data["target_values"].to(device)
        batch_labels = batch_data["batch_labels"].to(device)

        src_key_padding_mask = input_gene_ids.eq(vocab[pad_token])
        with torch.cuda.amp.autocast(enabled=config.amp):
            output_dict = model(
                input_gene_ids,
                input_values,
                src_key_padding_mask=src_key_padding_mask,
                batch_labels=batch_labels if DSBN else None,
                MVC=config.GEPC,
                ECS=config.ecs_thres > 0,
            )

            masked_positions = input_values.eq(mask_value)  # the postions to predict
            loss = loss_mse = criterion(
                output_dict["mlm_output"], target_values, masked_positions
            )
            metrics_to_log = {"train/mse": loss_mse.item()}
            if explicit_zero_prob:
                loss_zero_log_prob = criterion_neg_log_bernoulli(
                    output_dict["mlm_zero_probs"], target_values, masked_positions
                )
                loss = loss + loss_zero_log_prob
                metrics_to_log.update({"train/nzlp": loss_zero_log_prob.item()})
            if config.GEPC:
                loss_gepc = criterion(
                    output_dict["mvc_output"], target_values, masked_positions
                )
                loss = loss + loss_gepc
                metrics_to_log.update({"train/mvc": loss_gepc.item()})
            if config.GEPC and explicit_zero_prob:
                loss_gepc_zero_log_prob = criterion_neg_log_bernoulli(
                    output_dict["mvc_zero_probs"], target_values, masked_positions
                )
                loss = loss + loss_gepc_zero_log_prob
                metrics_to_log.update(
                    {"train/mvc_nzlp": loss_gepc_zero_log_prob.item()}
                )
            if config.ecs_thres > 0:
                loss_ecs = 10 * output_dict["loss_ecs"]
                loss = loss + loss_ecs
                metrics_to_log.update({"train/ecs": loss_ecs.item()})
            loss_dab = criterion_dab(output_dict["dab_output"], batch_labels)
            loss = loss + config.dab_weight * loss_dab
            metrics_to_log.update({"train/dab": loss_dab.item()})

        model.zero_grad()
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        with warnings.catch_warnings(record=True) as w:
            warnings.filterwarnings("always")
            torch.nn.utils.clip_grad_norm_(
                model.parameters(),
                1.0,
                error_if_nonfinite=False if scaler.is_enabled() else True,
            )
            if len(w) > 0:
                logger.warning(
                    f"Found infinite gradient. This may be caused by the gradient "
                    f"scaler. The current scale is {scaler.get_scale()}. This warning "
                    "can be ignored if no longer occurs after autoscaling of the scaler."
                )
        scaler.step(optimizer)
        scaler.update()

        wandb.log(metrics_to_log)

        with torch.no_grad():
            mre = masked_relative_error(
                output_dict["mlm_output"], target_values, masked_positions
            )

        total_loss += loss.item()
        total_mse += loss_mse.item()
        total_gepc += loss_gepc.item() if config.GEPC else 0.0
        total_error += mre.item()
        if batch % log_interval == 0 and batch > 0:
            lr = scheduler.get_last_lr()[0]
            ms_per_batch = (time.time() - start_time) * 1000 / log_interval
            cur_loss = total_loss / log_interval
            cur_mse = total_mse / log_interval
            cur_gepc = total_gepc / log_interval if config.GEPC else 0.0
            cur_error = total_error / log_interval
            # ppl = math.exp(cur_loss)
            logger.info(
                f"| epoch {epoch:3d} | {batch:3d}/{num_batches:3d} batches | "
                f"lr {lr:05.4f} | ms/batch {ms_per_batch:5.2f} | "
                f"loss {cur_loss:5.2f} | mse {cur_mse:5.2f} | mre {cur_error:5.2f} |"
                + (f"gepc {cur_gepc:5.2f} |" if config.GEPC else "")
            )
            total_loss = 0
            total_mse = 0
            total_gepc = 0
            total_error = 0
            start_time = time.time()


def define_wandb_metrcis():
    wandb.define_metric("valid/mse", summary="min", step_metric="epoch")
    wandb.define_metric("valid/mre", summary="min", step_metric="epoch")
    wandb.define_metric("valid/dab", summary="min", step_metric="epoch")
    wandb.define_metric("valid/sum_mse_dab", summary="min", step_metric="epoch")
    wandb.define_metric("test/avg_bio", summary="max")


def evaluate(model: nn.Module, loader: DataLoader) -> float:
    """
    Evaluate the model on the evaluation data.
    """
    model.eval()
    total_loss = 0.0
    total_error = 0.0
    total_dab = 0.0
    total_num = 0
    with torch.no_grad():
        for batch_data in loader:
            input_gene_ids = batch_data["gene_ids"].to(device)
            input_values = batch_data["values"].to(device)
            target_values = batch_data["target_values"].to(device)
            batch_labels = batch_data["batch_labels"].to(device)

            src_key_padding_mask = input_gene_ids.eq(vocab[pad_token])
            with torch.cuda.amp.autocast(enabled=config.amp):
                output_dict = model(
                    input_gene_ids,
                    input_values,
                    src_key_padding_mask=src_key_padding_mask,
                    batch_labels=batch_labels if DSBN else None,
                )
                output_values = output_dict["mlm_output"]

                masked_positions = input_values.eq(mask_value)
                loss = criterion(output_values, target_values, masked_positions)
                loss_dab = criterion_dab(output_dict["dab_output"], batch_labels)

            total_loss += loss.item() * len(input_gene_ids)
            total_error += masked_relative_error(
                output_values, target_values, masked_positions
            ).item() * len(input_gene_ids)
            total_dab += loss_dab.item() * len(input_gene_ids)
            total_num += len(input_gene_ids)

    wandb.log(
        {
            "valid/mse": total_loss / total_num,
            "valid/mre": total_error / total_num,
            "valid/dab": total_dab / total_num,
            "valid/sum_mse_dab": (total_loss + config.dab_weight * total_dab)
            / total_num,
            "epoch": epoch,
        },
    )

    return total_loss / total_num, total_error / total_num


def eval_testdata(
    model: nn.Module,
    adata_t: AnnData,
    include_types: List[str] = ["cls"],
) -> Optional[Dict]:
    """evaluate the model on test dataset of adata_t"""
    model.eval()

    # copy adata_t to avoid reuse previously computed results stored in adata_t
    adata_t = adata_t.copy()

    all_counts = (
        adata_t.layers[input_layer_key].toarray()
        if issparse(adata_t.layers[input_layer_key])
        else adata_t.layers[input_layer_key]
    )

    celltypes_labels = adata_t.obs["celltype"].tolist()
    celltypes_labels = np.array(celltypes_labels)

    batch_ids = adata_t.obs["batch_id"].tolist()
    batch_ids = np.array(batch_ids)

    # Evaluate cls cell embeddings
    if "cls" in include_types:
        logger.info("Evaluating cls cell embeddings")
        tokenized_all = tokenize_and_pad_batch(
            all_counts,
            gene_ids,
            max_len=max_seq_len,
            vocab=vocab,
            pad_token=pad_token,
            pad_value=pad_value,
            append_cls=True,  # append <cls> token at the beginning
            include_zero_gene=True,
        )
        all_gene_ids, all_values = tokenized_all["genes"], tokenized_all["values"]
        src_key_padding_mask = all_gene_ids.eq(vocab[pad_token])
        with torch.no_grad(), torch.cuda.amp.autocast(enabled=config.amp):
            cell_embeddings = model.encode_batch(
                all_gene_ids,
                all_values.float(),
                src_key_padding_mask=src_key_padding_mask,
                batch_size=config.batch_size,
                batch_labels=torch.from_numpy(batch_ids).long() if DSBN else None,
                time_step=0,
                return_np=True,
            )
        cell_embeddings = cell_embeddings / np.linalg.norm(
            cell_embeddings, axis=1, keepdims=True
        )

        adata_t.obsm["X_scGPT"] = cell_embeddings

        results = {}
        try:
            results = eval_scib_metrics(adata_t)
        except Exception as e:
            traceback.print_exc()
            logger.error(e)

        sc.pp.neighbors(adata_t, use_rep="X_scGPT")
        sc.tl.umap(adata_t, min_dist=0.3)
        fig = sc.pl.umap(
            adata_t,
            color=["str_batch"],
            title=[f"batch, avg_bio = {results.get('avg_bio', 0.0):.4f}"],
            frameon=False,
            return_fig=True,
            show=False,
        )

        results["batch_umap"] = fig

        sc.pp.neighbors(adata_t, use_rep="X_scGPT")
        sc.tl.umap(adata_t, min_dist=0.3)
        fig = sc.pl.umap(
            adata_t,
            color=["celltype"],
            title=[
                f"celltype, avg_bio = {results.get('avg_bio', 0.0):.4f}",
            ],
            frameon=False,
            return_fig=True,
            show=False,
        )

        results["celltype_umap"] = fig

    if len(include_types) == 1:
        return results

# %% [markdown]
# ## Step 4: Finetune scGPT with task-specific objectives

# %%
best_val_loss = float("inf")
best_avg_bio = 0.0
best_model = None
define_wandb_metrcis()

for epoch in range(1, config.epochs + 1):
    epoch_start_time = time.time()
    train_data_pt, valid_data_pt = prepare_data(sort_seq_batch=per_seq_batch_sample)
    train_loader = prepare_dataloader(
        train_data_pt,
        batch_size=config.batch_size,
        shuffle=False,
        intra_domain_shuffle=True,
        drop_last=False,
    )
    valid_loader = prepare_dataloader(
        valid_data_pt,
        batch_size=config.batch_size,
        shuffle=False,
        intra_domain_shuffle=False,
        drop_last=False,
    )

    if config.do_train:
        train(
            model,
            loader=train_loader,
        )
    val_loss, val_mre = evaluate(
        model,
        loader=valid_loader,
    )
    elapsed = time.time() - epoch_start_time
    logger.info("-" * 89)
    logger.info(
        f"| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | "
        f"valid loss/mse {val_loss:5.4f} | mre {val_mre:5.4f}"
    )
    logger.info("-" * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        best_model_epoch = epoch
        logger.info(f"Best model with score {best_val_loss:5.4f}")

    if epoch % config.save_eval_interval == 0 or epoch == config.epochs:
        logger.info(f"Saving model to {save_dir}")
        torch.save(best_model.state_dict(), save_dir / f"model_e{best_model_epoch}.pt")

        # eval on testdata
        results = eval_testdata(
            best_model,
            adata_t=adata_sorted if per_seq_batch_sample else adata,
            include_types=["cls"],
        )
        results["batch_umap"].savefig(
            save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png", dpi=300
        )

        results["celltype_umap"].savefig(
            save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png", dpi=300
        )
        metrics_to_log = {"test/" + k: v for k, v in results.items()}
        metrics_to_log["test/batch_umap"] = wandb.Image(
            str(save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )

        metrics_to_log["test/celltype_umap"] = wandb.Image(
            str(save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )
        metrics_to_log["test/best_model_epoch"] = best_model_epoch
        wandb.log(metrics_to_log)
        wandb.log({"avg_bio": results.get("avg_bio", 0.0)})

    scheduler.step()
# Out:
# random masking at epoch   1, ratio of masked values in train:  0.3997
# scGPT - INFO - | epoch   1 | 100/19390 batches | lr 0.0001 | ms/batch 398.48 | loss 106.88 | mse 48.88 | mre 1669344.52 |gepc 47.62 |
# scGPT - INFO - | epoch   1 | 200/19390 batches | lr 0.0001 | ms/batch 397.96 | loss 91.12 | mse 45.78 | mre 1352780.31 |gepc 35.56 |
# scGPT - INFO - | epoch   1 | 300/19390 batches | lr 0.0001 | ms/batch 400.73 | loss 75.44 | mse 33.25 | mre 1268223.51 |gepc 32.43 |
# scGPT - INFO - | epoch   1 | 400/19390 batches | lr 0.0001 | ms/batch 402.18 | loss 67.14 | mse 25.64 | mre 1069805.61 |gepc 31.67 |
# scGPT - INFO - | epoch   1 | 500/19390 batches | lr 0.0001 | ms/batch 403.04 | loss 59.73 | mse 22.26 | mre 819303.08 |gepc 27.63 |
# scGPT - INFO - | epoch   1 | 600/19390 batches | lr 0.0001 | ms/batch 403.08 | loss 58.35 | mse 21.55 | mre 810588.38 |gepc 26.98 |
# scGPT - INFO - | epoch   1 | 700/19390 batches | lr 0.0001 | ms/batch 403.25 | loss 58.65 | mse 21.74 | mre 843913.27 |gepc 27.11 |
# scGPT - INFO - | epoch   1 | 800/19390 batches | lr 0.0001 | ms/batch 403.52 | loss 55.94 | mse 20.44 | mre 838364.24 |gepc 25.75 |
# scGPT - INFO - | epoch   1 | 900/19390 batches | lr 0.0001 | ms/batch 404.25 | loss 57.12 | mse 20.43 | mre 774701.27 |gepc 27.00 |
# scGPT - INFO - | epoch   1 | 1000/19390 batches | lr 0.0001 | ms/batch 405.09 | loss 56.37 | mse 20.54 | mre 757834.78 |gepc 26.11 |
# scGPT - INFO - | epoch   1 | 1100/19390 batches | lr 0.0001 | ms/batch 404.37 | loss 53.30 | mse 19.65 | mre 780572.32 |gepc 23.95 |
# scGPT - INFO - | epoch   1 | 1200/19390 batches | lr 0.0001 | ms/batch 404.35 | loss 52.13 | mse 19.16 | mre 706236.60 |gepc 23.32 |
# scGPT - INFO - | epoch   1 | 1300/19390 batches | lr 0.0001 | ms/batch 404.15 | loss 53.05 | mse 19.47 | mre 757924.52 |gepc 24.18 |
# scGPT - INFO - | epoch   1 | 1400/19390 batches | lr 0.0001 | ms/batch 404.03 | loss 52.02 | mse 19.31 | mre 746138.77 |gepc 23.34 |
# scGPT - INFO - | epoch   1 | 1500/19390 batches | lr 0.0001 | ms/batch 404.00 | loss 51.49 | mse 19.10 | mre 673991.84 |gepc 23.21 |
# scGPT - INFO - | epoch   1 | 1600/19390 batches | lr 0.0001 | ms/batch 403.79 | loss 51.97 | mse 19.37 | mre 749030.11 |gepc 23.61 |
# scGPT - INFO - | epoch   1 | 1700/19390 batches | lr 0.0001 | ms/batch 403.76 | loss 50.79 | mse 18.85 | mre 665846.18 |gepc 23.04 |
# scGPT - INFO - | epoch   1 | 1800/19390 batches | lr 0.0001 | ms/batch 403.75 | loss 50.41 | mse 19.17 | mre 718954.91 |gepc 23.13 |
# scGPT - INFO - | epoch   1 | 1900/19390 batches | lr 0.0001 | ms/batch 403.67 | loss 48.81 | mse 18.54 | mre 687127.87 |gepc 22.47 |
# scGPT - INFO - | epoch   1 | 2000/19390 batches | lr 0.0001 | ms/batch 404.32 | loss 49.20 | mse 18.72 | mre 707609.59 |gepc 23.00 |
# scGPT - INFO - | epoch   1 | 2100/19390 batches | lr 0.0001 | ms/batch 403.86 | loss 48.33 | mse 18.59 | mre 674030.36 |gepc 22.42 |
# scGPT - INFO - | epoch   1 | 2200/19390 batches | lr 0.0001 | ms/batch 403.78 | loss 48.39 | mse 18.47 | mre 664663.57 |gepc 22.99 |
# scGPT - INFO - | epoch   1 | 2300/19390 batches | lr 0.0001 | ms/batch 403.73 | loss 47.96 | mse 18.86 | mre 680703.08 |gepc 22.68 |
# scGPT - INFO - | epoch   1 | 2400/19390 batches | lr 0.0001 | ms/batch 403.69 | loss 47.45 | mse 18.66 | mre 674974.99 |gepc 22.56 |
# scGPT - INFO - | epoch   1 | 2500/19390 batches | lr 0.0001 | ms/batch 403.78 | loss 44.72 | mse 17.65 | mre 612979.60 |gepc 21.15 |
# scGPT - INFO - | epoch   1 | 2600/19390 batches | lr 0.0001 | ms/batch 403.72 | loss 45.86 | mse 18.39 | mre 642513.73 |gepc 21.77 |
# scGPT - INFO - | epoch   1 | 2700/19390 batches | lr 0.0001 | ms/batch 403.83 | loss 44.77 | mse 17.92 | mre 621507.43 |gepc 21.11 |
# scGPT - INFO - | epoch   1 | 2800/19390 batches | lr 0.0001 | ms/batch 403.98 | loss 44.35 | mse 17.67 | mre 601910.95 |gepc 21.02 |
# scGPT - INFO - | epoch   1 | 2900/19390 batches | lr 0.0001 | ms/batch 403.68 | loss 44.98 | mse 18.18 | mre 597892.42 |gepc 21.22 |
# scGPT - INFO - | epoch   1 | 3000/19390 batches | lr 0.0001 | ms/batch 404.27 | loss 43.58 | mse 17.64 | mre 589644.08 |gepc 20.40 |
# scGPT - INFO - | epoch   1 | 3100/19390 batches | lr 0.0001 | ms/batch 403.94 | loss 44.01 | mse 17.96 | mre 586346.53 |gepc 20.66 |
# scGPT - INFO - | epoch   1 | 3200/19390 batches | lr 0.0001 | ms/batch 404.30 | loss 44.44 | mse 18.07 | mre 581221.03 |gepc 20.97 |
# scGPT - INFO - | epoch   1 | 3300/19390 batches | lr 0.0001 | ms/batch 403.91 | loss 44.31 | mse 17.75 | mre 577997.86 |gepc 21.26 |
# scGPT - INFO - | epoch   1 | 3400/19390 batches | lr 0.0001 | ms/batch 403.92 | loss 43.33 | mse 17.62 | mre 568957.14 |gepc 20.41 |
# scGPT - INFO - | epoch   1 | 3500/19390 batches | lr 0.0001 | ms/batch 403.72 | loss 43.81 | mse 17.90 | mre 580167.08 |gepc 20.68 |
# scGPT - INFO - | epoch   1 | 3600/19390 batches | lr 0.0001 | ms/batch 403.74 | loss 42.14 | mse 17.07 | mre 548223.65 |gepc 19.79 |
# scGPT - INFO - | epoch   1 | 3700/19390 batches | lr 0.0001 | ms/batch 403.91 | loss 42.74 | mse 17.55 | mre 560379.54 |gepc 19.98 |
# scGPT - INFO - | epoch   1 | 3800/19390 batches | lr 0.0001 | ms/batch 400.97 | loss 42.83 | mse 17.32 | mre 546683.28 |gepc 20.34 |
# scGPT - INFO - | epoch   1 | 3900/19390 batches | lr 0.0001 | ms/batch 404.24 | loss 62.23 | mse 24.04 | mre 841134.17 |gepc 30.56 |
# scGPT - INFO - | epoch   1 | 4000/19390 batches | lr 0.0001 | ms/batch 404.71 | loss 54.26 | mse 22.61 | mre 737180.43 |gepc 26.27 |
# scGPT - INFO - | epoch   1 | 4100/19390 batches | lr 0.0001 | ms/batch 404.21 | loss 51.91 | mse 21.71 | mre 703051.67 |gepc 24.97 |
# scGPT - INFO - | epoch   1 | 4200/19390 batches | lr 0.0001 | ms/batch 404.20 | loss 52.33 | mse 21.84 | mre 706935.90 |gepc 25.38 |
# scGPT - INFO - | epoch   1 | 4300/19390 batches | lr 0.0001 | ms/batch 404.16 | loss 50.02 | mse 20.60 | mre 667270.58 |gepc 24.35 |
# scGPT - INFO - | epoch   1 | 4400/19390 batches | lr 0.0001 | ms/batch 404.10 | loss 50.87 | mse 21.35 | mre 679992.42 |gepc 24.53 |
# scGPT - INFO - | epoch   1 | 4500/19390 batches | lr 0.0001 | ms/batch 404.20 | loss 49.73 | mse 20.84 | mre 676205.86 |gepc 23.90 |
# scGPT - INFO - | epoch   1 | 4600/19390 batches | lr 0.0001 | ms/batch 404.11 | loss 50.24 | mse 20.86 | mre 676103.30 |gepc 24.39 |
# scGPT - INFO - | epoch   1 | 4700/19390 batches | lr 0.0001 | ms/batch 404.41 | loss 49.60 | mse 20.59 | mre 660673.11 |gepc 24.03 |
# scGPT - INFO - | epoch   1 | 4800/19390 batches | lr 0.0001 | ms/batch 404.13 | loss 48.47 | mse 20.11 | mre 657819.41 |gepc 23.45 |
# scGPT - INFO - | epoch   1 | 4900/19390 batches | lr 0.0001 | ms/batch 404.31 | loss 48.89 | mse 20.56 | mre 658811.56 |gepc 23.48 |
# scGPT - INFO - | epoch   1 | 5000/19390 batches | lr 0.0001 | ms/batch 404.86 | loss 49.91 | mse 21.04 | mre 678249.08 |gepc 24.01 |
# scGPT - INFO - | epoch   1 | 5100/19390 batches | lr 0.0001 | ms/batch 404.25 | loss 48.84 | mse 20.45 | mre 656685.48 |gepc 23.53 |
# scGPT - INFO - | epoch   1 | 5200/19390 batches | lr 0.0001 | ms/batch 404.22 | loss 47.99 | mse 20.02 | mre 650493.35 |gepc 23.11 |
# scGPT - INFO - | epoch   1 | 5300/19390 batches | lr 0.0001 | ms/batch 404.13 | loss 48.25 | mse 20.23 | mre 655630.03 |gepc 23.22 |
# scGPT - INFO - | epoch   1 | 5400/19390 batches | lr 0.0001 | ms/batch 404.48 | loss 47.38 | mse 19.71 | mre 644567.04 |gepc 22.86 |
# scGPT - INFO - | epoch   1 | 5500/19390 batches | lr 0.0001 | ms/batch 404.35 | loss 47.40 | mse 19.87 | mre 642582.91 |gepc 22.81 |
# scGPT - INFO - | epoch   1 | 5600/19390 batches | lr 0.0001 | ms/batch 404.33 | loss 46.25 | mse 19.40 | mre 631572.16 |gepc 22.14 |
# scGPT - INFO - | epoch   1 | 5700/19390 batches | lr 0.0001 | ms/batch 404.48 | loss 46.01 | mse 19.33 | mre 623814.43 |gepc 22.00 |
# scGPT - INFO - | epoch   1 | 5800/19390 batches | lr 0.0001 | ms/batch 404.54 | loss 45.94 | mse 19.38 | mre 625646.86 |gepc 21.94 |
# scGPT - INFO - | epoch   1 | 5900/19390 batches | lr 0.0001 | ms/batch 404.31 | loss 45.80 | mse 19.30 | mre 623413.11 |gepc 21.83 |
# scGPT - INFO - | epoch   1 | 6000/19390 batches | lr 0.0001 | ms/batch 404.88 | loss 45.99 | mse 19.40 | mre 624450.40 |gepc 21.98 |
# scGPT - INFO - | epoch   1 | 6100/19390 batches | lr 0.0001 | ms/batch 404.43 | loss 45.40 | mse 19.20 | mre 624661.05 |gepc 21.64 |
# scGPT - INFO - | epoch   1 | 6200/19390 batches | lr 0.0001 | ms/batch 404.44 | loss 45.16 | mse 18.92 | mre 605881.15 |gepc 21.66 |
# scGPT - INFO - | epoch   1 | 6300/19390 batches | lr 0.0001 | ms/batch 404.30 | loss 44.19 | mse 18.61 | mre 604229.29 |gepc 20.98 |
# scGPT - INFO - | epoch   1 | 6400/19390 batches | lr 0.0001 | ms/batch 404.77 | loss 45.10 | mse 19.06 | mre 618201.11 |gepc 21.48 |
# scGPT - INFO - | epoch   1 | 6500/19390 batches | lr 0.0001 | ms/batch 404.66 | loss 44.68 | mse 18.93 | mre 614136.84 |gepc 21.19 |
# scGPT - INFO - | epoch   1 | 6600/19390 batches | lr 0.0001 | ms/batch 404.38 | loss 45.29 | mse 19.12 | mre 620340.99 |gepc 21.63 |
# scGPT - INFO - | epoch   1 | 6700/19390 batches | lr 0.0001 | ms/batch 404.52 | loss 45.37 | mse 19.07 | mre 617009.53 |gepc 21.77 |
# scGPT - INFO - | epoch   1 | 6800/19390 batches | lr 0.0001 | ms/batch 404.95 | loss 44.62 | mse 18.90 | mre 612907.91 |gepc 21.13 |
# scGPT - INFO - | epoch   1 | 6900/19390 batches | lr 0.0001 | ms/batch 404.47 | loss 44.59 | mse 18.91 | mre 617651.94 |gepc 21.16 |
# scGPT - INFO - | epoch   1 | 7000/19390 batches | lr 0.0001 | ms/batch 405.34 | loss 45.87 | mse 19.55 | mre 635570.23 |gepc 21.77 |
# scGPT - INFO - | epoch   1 | 7100/19390 batches | lr 0.0001 | ms/batch 404.89 | loss 45.35 | mse 19.21 | mre 620830.02 |gepc 21.65 |
# scGPT - INFO - | epoch   1 | 7200/19390 batches | lr 0.0001 | ms/batch 404.77 | loss 44.93 | mse 19.14 | mre 623999.79 |gepc 21.33 |
# scGPT - INFO - | epoch   1 | 7300/19390 batches | lr 0.0001 | ms/batch 404.80 | loss 45.49 | mse 19.34 | mre 628365.15 |gepc 21.69 |
# scGPT - INFO - | epoch   1 | 7400/19390 batches | lr 0.0001 | ms/batch 404.82 | loss 45.22 | mse 19.23 | mre 627400.58 |gepc 21.49 |
# scGPT - INFO - | epoch   1 | 7500/19390 batches | lr 0.0001 | ms/batch 402.18 | loss 49.72 | mse 19.45 | mre 626878.86 |gepc 23.61 |
# scGPT - INFO - | epoch   1 | 7600/19390 batches | lr 0.0001 | ms/batch 404.30 | loss 46.15 | mse 19.15 | mre 622273.74 |gepc 21.46 |
# scGPT - INFO - | epoch   1 | 7700/19390 batches | lr 0.0001 | ms/batch 404.33 | loss 41.89 | mse 17.75 | mre 579212.90 |gepc 19.18 |
# scGPT - INFO - | epoch   1 | 7800/19390 batches | lr 0.0001 | ms/batch 404.65 | loss 39.76 | mse 16.69 | mre 545043.64 |gepc 18.17 |
# scGPT - INFO - | epoch   1 | 7900/19390 batches | lr 0.0001 | ms/batch 404.40 | loss 38.46 | mse 16.02 | mre 527589.74 |gepc 17.52 |
# scGPT - INFO - | epoch   1 | 8000/19390 batches | lr 0.0001 | ms/batch 405.11 | loss 38.51 | mse 16.18 | mre 528053.99 |gepc 17.50 |
# scGPT - INFO - | epoch   1 | 8100/19390 batches | lr 0.0001 | ms/batch 404.64 | loss 39.03 | mse 16.42 | mre 536487.51 |gepc 17.82 |
# scGPT - INFO - | epoch   1 | 8200/19390 batches | lr 0.0001 | ms/batch 404.28 | loss 37.63 | mse 15.86 | mre 521372.69 |gepc 17.01 |
# scGPT - INFO - | epoch   1 | 8300/19390 batches | lr 0.0001 | ms/batch 404.45 | loss 37.38 | mse 15.69 | mre 510503.10 |gepc 16.88 |
# scGPT - INFO - | epoch   1 | 8400/19390 batches | lr 0.0001 | ms/batch 404.50 | loss 37.78 | mse 15.88 | mre 519578.36 |gepc 17.09 |
# scGPT - INFO - | epoch   1 | 8500/19390 batches | lr 0.0001 | ms/batch 404.30 | loss 37.41 | mse 15.69 | mre 519993.26 |gepc 16.94 |
# scGPT - INFO - | epoch   1 | 8600/19390 batches | lr 0.0001 | ms/batch 404.36 | loss 37.40 | mse 15.77 | mre 519193.81 |gepc 16.88 |
# scGPT - INFO - | epoch   1 | 8700/19390 batches | lr 0.0001 | ms/batch 404.28 | loss 37.16 | mse 15.65 | mre 509823.32 |gepc 16.80 |
# scGPT - INFO - | epoch   1 | 8800/19390 batches | lr 0.0001 | ms/batch 404.52 | loss 37.27 | mse 15.66 | mre 512022.88 |gepc 16.88 |
# scGPT - INFO - | epoch   1 | 8900/19390 batches | lr 0.0001 | ms/batch 404.45 | loss 36.91 | mse 15.51 | mre 505851.55 |gepc 16.65 |
# scGPT - INFO - | epoch   1 | 9000/19390 batches | lr 0.0001 | ms/batch 404.95 | loss 41.34 | mse 15.96 | mre 543423.89 |gepc 19.04 |
# scGPT - INFO - | epoch   1 | 9100/19390 batches | lr 0.0001 | ms/batch 404.51 | loss 50.21 | mse 18.28 | mre 571433.07 |gepc 20.87 |
# scGPT - INFO - | epoch   1 | 9200/19390 batches | lr 0.0001 | ms/batch 404.80 | loss 46.73 | mse 18.30 | mre 605332.84 |gepc 20.90 |
# scGPT - INFO - | epoch   1 | 9300/19390 batches | lr 0.0001 | ms/batch 404.57 | loss 39.80 | mse 16.65 | mre 548212.28 |gepc 18.38 |
# scGPT - INFO - | epoch   1 | 9400/19390 batches | lr 0.0001 | ms/batch 404.64 | loss 40.24 | mse 16.99 | mre 550626.00 |gepc 18.58 |
# scGPT - INFO - | epoch   1 | 9500/19390 batches | lr 0.0001 | ms/batch 404.88 | loss 39.22 | mse 16.56 | mre 538012.26 |gepc 18.08 |
# scGPT - INFO - | epoch   1 | 9600/19390 batches | lr 0.0001 | ms/batch 404.82 | loss 39.70 | mse 16.78 | mre 543883.72 |gepc 18.37 |
# scGPT - INFO - | epoch   1 | 9700/19390 batches | lr 0.0001 | ms/batch 405.06 | loss 38.28 | mse 16.08 | mre 525872.60 |gepc 17.68 |
# scGPT - INFO - | epoch   1 | 9800/19390 batches | lr 0.0001 | ms/batch 404.60 | loss 38.14 | mse 16.04 | mre 528080.86 |gepc 17.57 |
# scGPT - INFO - | epoch   1 | 9900/19390 batches | lr 0.0001 | ms/batch 404.56 | loss 37.86 | mse 15.93 | mre 513847.31 |gepc 17.40 |
# scGPT - INFO - | epoch   1 | 10000/19390 batches | lr 0.0001 | ms/batch 405.27 | loss 37.96 | mse 15.99 | mre 529065.91 |gepc 17.48 |
# scGPT - INFO - | epoch   1 | 10100/19390 batches | lr 0.0001 | ms/batch 404.72 | loss 37.65 | mse 15.86 | mre 520503.37 |gepc 17.30 |
# scGPT - INFO - | epoch   1 | 10200/19390 batches | lr 0.0001 | ms/batch 404.86 | loss 37.44 | mse 15.69 | mre 515826.52 |gepc 17.28 |
# scGPT - INFO - | epoch   1 | 10300/19390 batches | lr 0.0001 | ms/batch 404.66 | loss 38.02 | mse 15.98 | mre 530840.21 |gepc 17.56 |
# scGPT - INFO - | epoch   1 | 10400/19390 batches | lr 0.0001 | ms/batch 404.88 | loss 38.45 | mse 16.16 | mre 527465.54 |gepc 17.83 |
# scGPT - INFO - | epoch   1 | 10500/19390 batches | lr 0.0001 | ms/batch 404.75 | loss 36.97 | mse 15.49 | mre 513051.62 |gepc 17.01 |
# scGPT - INFO - | epoch   1 | 10600/19390 batches | lr 0.0001 | ms/batch 404.64 | loss 37.03 | mse 15.56 | mre 515138.78 |gepc 17.05 |
# scGPT - INFO - | epoch   1 | 10700/19390 batches | lr 0.0001 | ms/batch 404.87 | loss 37.10 | mse 15.57 | mre 506918.34 |gepc 17.12 |
# scGPT - INFO - | epoch   1 | 10800/19390 batches | lr 0.0001 | ms/batch 404.64 | loss 37.02 | mse 15.52 | mre 511370.78 |gepc 17.09 |
# scGPT - INFO - | epoch   1 | 10900/19390 batches | lr 0.0001 | ms/batch 405.00 | loss 36.70 | mse 15.38 | mre 502126.83 |gepc 16.91 |
# scGPT - INFO - | epoch   1 | 11000/19390 batches | lr 0.0001 | ms/batch 405.34 | loss 36.05 | mse 15.09 | mre 495917.10 |gepc 16.55 |
# scGPT - INFO - | epoch   1 | 11100/19390 batches | lr 0.0001 | ms/batch 404.54 | loss 36.85 | mse 15.49 | mre 515974.23 |gepc 16.98 |
# scGPT - INFO - | epoch   1 | 11200/19390 batches | lr 0.0001 | ms/batch 405.11 | loss 35.72 | mse 14.96 | mre 488316.78 |gepc 16.38 |
# scGPT - INFO - | epoch   1 | 11300/19390 batches | lr 0.0001 | ms/batch 404.62 | loss 36.70 | mse 15.43 | mre 511577.17 |gepc 16.89 |
# scGPT - INFO - | epoch   1 | 11400/19390 batches | lr 0.0001 | ms/batch 404.71 | loss 36.79 | mse 15.44 | mre 512417.30 |gepc 17.00 |
# scGPT - INFO - | epoch   1 | 11500/19390 batches | lr 0.0001 | ms/batch 404.80 | loss 36.42 | mse 15.30 | mre 497055.71 |gepc 16.79 |
# scGPT - INFO - | epoch   1 | 11600/19390 batches | lr 0.0001 | ms/batch 404.64 | loss 36.37 | mse 15.29 | mre 502221.92 |gepc 16.76 |
# scGPT - INFO - | epoch   1 | 11700/19390 batches | lr 0.0001 | ms/batch 404.66 | loss 35.86 | mse 15.08 | mre 497263.59 |gepc 16.43 |
# scGPT - INFO - | epoch   1 | 11800/19390 batches | lr 0.0001 | ms/batch 404.73 | loss 35.71 | mse 14.94 | mre 494456.88 |gepc 16.40 |
# scGPT - INFO - | epoch   1 | 11900/19390 batches | lr 0.0001 | ms/batch 404.95 | loss 36.06 | mse 15.17 | mre 503214.74 |gepc 16.54 |
# scGPT - INFO - | epoch   1 | 12000/19390 batches | lr 0.0001 | ms/batch 405.23 | loss 35.81 | mse 15.02 | mre 498607.17 |gepc 16.46 |
# scGPT - INFO - | epoch   1 | 12100/19390 batches | lr 0.0001 | ms/batch 404.67 | loss 35.38 | mse 14.84 | mre 486754.00 |gepc 16.22 |
# scGPT - INFO - | epoch   1 | 12200/19390 batches | lr 0.0001 | ms/batch 405.17 | loss 35.84 | mse 15.08 | mre 495236.62 |gepc 16.46 |
# scGPT - INFO - | epoch   1 | 12300/19390 batches | lr 0.0001 | ms/batch 405.09 | loss 35.30 | mse 14.83 | mre 491963.08 |gepc 16.17 |
# scGPT - INFO - | epoch   1 | 12400/19390 batches | lr 0.0001 | ms/batch 404.99 | loss 34.95 | mse 14.67 | mre 488025.13 |gepc 15.97 |
# scGPT - INFO - | epoch   1 | 12500/19390 batches | lr 0.0001 | ms/batch 404.79 | loss 35.96 | mse 15.19 | mre 496350.90 |gepc 16.47 |
# scGPT - INFO - | epoch   1 | 12600/19390 batches | lr 0.0001 | ms/batch 404.96 | loss 34.36 | mse 14.42 | mre 476684.62 |gepc 15.65 |
# scGPT - INFO - | epoch   1 | 12700/19390 batches | lr 0.0001 | ms/batch 404.68 | loss 35.79 | mse 15.08 | mre 495483.83 |gepc 16.42 |
# scGPT - INFO - | epoch   1 | 12800/19390 batches | lr 0.0001 | ms/batch 404.76 | loss 35.18 | mse 14.77 | mre 488737.23 |gepc 16.15 |
# scGPT - INFO - | epoch   1 | 12900/19390 batches | lr 0.0001 | ms/batch 404.66 | loss 35.42 | mse 14.94 | mre 488828.41 |gepc 16.19 |
# scGPT - INFO - | epoch   1 | 13000/19390 batches | lr 0.0001 | ms/batch 405.34 | loss 34.96 | mse 14.69 | mre 485190.67 |gepc 15.97 |
# scGPT - INFO - | epoch   1 | 13100/19390 batches | lr 0.0001 | ms/batch 404.63 | loss 34.85 | mse 14.69 | mre 483636.42 |gepc 15.90 |
# scGPT - INFO - | epoch   1 | 13200/19390 batches | lr 0.0001 | ms/batch 404.57 | loss 35.53 | mse 15.01 | mre 499241.53 |gepc 16.23 |
# scGPT - INFO - | epoch   1 | 13300/19390 batches | lr 0.0001 | ms/batch 404.76 | loss 34.79 | mse 14.61 | mre 489205.66 |gepc 15.89 |
# scGPT - INFO - | epoch   1 | 13400/19390 batches | lr 0.0001 | ms/batch 404.77 | loss 35.18 | mse 14.79 | mre 483758.05 |gepc 16.10 |
# scGPT - INFO - | epoch   1 | 13500/19390 batches | lr 0.0001 | ms/batch 404.60 | loss 34.89 | mse 14.71 | mre 483942.97 |gepc 15.90 |
# scGPT - INFO - | epoch   1 | 13600/19390 batches | lr 0.0001 | ms/batch 404.90 | loss 34.48 | mse 14.50 | mre 483278.61 |gepc 15.72 |
# scGPT - INFO - | epoch   1 | 13700/19390 batches | lr 0.0001 | ms/batch 404.79 | loss 35.40 | mse 14.95 | mre 493937.13 |gepc 16.16 |
# scGPT - INFO - | epoch   1 | 13800/19390 batches | lr 0.0001 | ms/batch 404.73 | loss 34.79 | mse 14.66 | mre 482217.89 |gepc 15.83 |
# scGPT - INFO - | epoch   1 | 13900/19390 batches | lr 0.0001 | ms/batch 404.74 | loss 34.80 | mse 14.65 | mre 479937.36 |gepc 15.90 |
# scGPT - INFO - | epoch   1 | 14000/19390 batches | lr 0.0001 | ms/batch 405.23 | loss 35.44 | mse 14.95 | mre 495173.24 |gepc 16.20 |
# scGPT - INFO - | epoch   1 | 14100/19390 batches | lr 0.0001 | ms/batch 404.63 | loss 34.25 | mse 14.41 | mre 478582.49 |gepc 15.57 |
# scGPT - INFO - | epoch   1 | 14200/19390 batches | lr 0.0001 | ms/batch 404.65 | loss 34.66 | mse 14.60 | mre 479357.78 |gepc 15.78 |
# scGPT - INFO - | epoch   1 | 14300/19390 batches | lr 0.0001 | ms/batch 404.72 | loss 34.78 | mse 14.66 | mre 483145.63 |gepc 15.84 |
# scGPT - INFO - | epoch   1 | 14400/19390 batches | lr 0.0001 | ms/batch 404.71 | loss 33.83 | mse 14.13 | mre 470875.35 |gepc 15.43 |
# scGPT - INFO - | epoch   1 | 14500/19390 batches | lr 0.0001 | ms/batch 404.73 | loss 34.23 | mse 14.42 | mre 474026.35 |gepc 15.52 |
# scGPT - INFO - | epoch   1 | 14600/19390 batches | lr 0.0001 | ms/batch 404.83 | loss 34.44 | mse 14.51 | mre 475727.00 |gepc 15.66 |
# scGPT - INFO - | epoch   1 | 14700/19390 batches | lr 0.0001 | ms/batch 404.74 | loss 35.43 | mse 14.97 | mre 489466.98 |gepc 16.20 |
# scGPT - INFO - | epoch   1 | 14800/19390 batches | lr 0.0001 | ms/batch 404.78 | loss 33.61 | mse 14.15 | mre 471490.05 |gepc 15.21 |
# scGPT - INFO - | epoch   1 | 14900/19390 batches | lr 0.0001 | ms/batch 405.27 | loss 34.10 | mse 14.34 | mre 474725.68 |gepc 15.50 |
# scGPT - INFO - | epoch   1 | 15000/19390 batches | lr 0.0001 | ms/batch 405.19 | loss 34.31 | mse 14.46 | mre 475582.28 |gepc 15.63 |
# scGPT - INFO - | epoch   1 | 15100/19390 batches | lr 0.0001 | ms/batch 404.79 | loss 34.32 | mse 14.44 | mre 476772.71 |gepc 15.61 |
# scGPT - INFO - | epoch   1 | 15200/19390 batches | lr 0.0001 | ms/batch 404.79 | loss 34.07 | mse 14.30 | mre 476306.12 |gepc 15.51 |
# scGPT - INFO - | epoch   1 | 15300/19390 batches | lr 0.0001 | ms/batch 404.85 | loss 34.65 | mse 14.62 | mre 480044.28 |gepc 15.78 |
# scGPT - INFO - | epoch   1 | 15400/19390 batches | lr 0.0001 | ms/batch 404.99 | loss 34.72 | mse 14.64 | mre 485758.24 |gepc 15.84 |
# scGPT - INFO - | epoch   1 | 15500/19390 batches | lr 0.0001 | ms/batch 404.70 | loss 34.68 | mse 14.66 | mre 481795.80 |gepc 15.76 |
# scGPT - INFO - | epoch   1 | 15600/19390 batches | lr 0.0001 | ms/batch 404.84 | loss 34.93 | mse 14.69 | mre 484246.87 |gepc 16.02 |
# scGPT - INFO - | epoch   1 | 15700/19390 batches | lr 0.0001 | ms/batch 404.88 | loss 33.96 | mse 14.28 | mre 474531.60 |gepc 15.44 |
# scGPT - INFO - | epoch   1 | 15800/19390 batches | lr 0.0001 | ms/batch 404.56 | loss 33.69 | mse 14.19 | mre 465166.34 |gepc 15.27 |
# scGPT - INFO - | epoch   1 | 15900/19390 batches | lr 0.0001 | ms/batch 404.72 | loss 34.13 | mse 14.36 | mre 469796.67 |gepc 15.54 |
# scGPT - INFO - | epoch   1 | 16000/19390 batches | lr 0.0001 | ms/batch 405.28 | loss 34.32 | mse 14.46 | mre 477201.07 |gepc 15.59 |
# scGPT - INFO - | epoch   1 | 16100/19390 batches | lr 0.0001 | ms/batch 404.59 | loss 34.32 | mse 14.44 | mre 476831.24 |gepc 15.63 |
# scGPT - INFO - | epoch   1 | 16200/19390 batches | lr 0.0001 | ms/batch 404.69 | loss 34.64 | mse 14.68 | mre 487547.18 |gepc 15.73 |
# scGPT - INFO - | epoch   1 | 16300/19390 batches | lr 0.0001 | ms/batch 404.76 | loss 34.33 | mse 14.42 | mre 480560.47 |gepc 15.66 |
# scGPT - INFO - | epoch   1 | 16400/19390 batches | lr 0.0001 | ms/batch 404.69 | loss 33.93 | mse 14.27 | mre 466627.83 |gepc 15.44 |
# scGPT - INFO - | epoch   1 | 16500/19390 batches | lr 0.0001 | ms/batch 404.94 | loss 34.07 | mse 14.37 | mre 479769.80 |gepc 15.46 |
# scGPT - INFO - | epoch   1 | 16600/19390 batches | lr 0.0001 | ms/batch 405.17 | loss 33.42 | mse 14.07 | mre 464516.83 |gepc 15.12 |
# scGPT - INFO - | epoch   1 | 16700/19390 batches | lr 0.0001 | ms/batch 404.99 | loss 33.62 | mse 14.17 | mre 471536.76 |gepc 15.26 |
# scGPT - INFO - | epoch   1 | 16800/19390 batches | lr 0.0001 | ms/batch 404.93 | loss 34.03 | mse 14.34 | mre 476549.40 |gepc 15.45 |
# scGPT - INFO - | epoch   1 | 16900/19390 batches | lr 0.0001 | ms/batch 404.87 | loss 34.04 | mse 14.34 | mre 478933.00 |gepc 15.48 |
# scGPT - INFO - | epoch   1 | 17000/19390 batches | lr 0.0001 | ms/batch 405.34 | loss 34.31 | mse 14.44 | mre 475268.67 |gepc 15.62 |
# scGPT - INFO - | epoch   1 | 17100/19390 batches | lr 0.0001 | ms/batch 404.77 | loss 34.90 | mse 14.76 | mre 486896.36 |gepc 15.92 |
# scGPT - INFO - | epoch   1 | 17200/19390 batches | lr 0.0001 | ms/batch 404.48 | loss 34.59 | mse 14.59 | mre 477521.37 |gepc 15.77 |
# scGPT - INFO - | epoch   1 | 17300/19390 batches | lr 0.0001 | ms/batch 404.52 | loss 34.89 | mse 14.78 | mre 490940.03 |gepc 15.89 |
# scGPT - INFO - | epoch   1 | 17400/19390 batches | lr 0.0001 | ms/batch 404.75 | loss 33.02 | mse 13.89 | mre 459437.33 |gepc 14.91 |
# scGPT - INFO - | epoch   1 | 17500/19390 batches | lr 0.0001 | ms/batch 404.69 | loss 34.21 | mse 14.47 | mre 477924.01 |gepc 15.53 |
# scGPT - INFO - | epoch   1 | 17600/19390 batches | lr 0.0001 | ms/batch 404.62 | loss 33.93 | mse 14.29 | mre 469393.03 |gepc 15.44 |
# scGPT - INFO - | epoch   1 | 17700/19390 batches | lr 0.0001 | ms/batch 404.72 | loss 34.31 | mse 14.48 | mre 480900.24 |gepc 15.60 |
# scGPT - INFO - | epoch   1 | 17800/19390 batches | lr 0.0001 | ms/batch 404.69 | loss 32.70 | mse 13.73 | mre 457668.81 |gepc 14.76 |
# scGPT - INFO - | epoch   1 | 17900/19390 batches | lr 0.0001 | ms/batch 404.63 | loss 33.50 | mse 14.06 | mre 465019.00 |gepc 15.25 |
# scGPT - INFO - | epoch   1 | 18000/19390 batches | lr 0.0001 | ms/batch 405.14 | loss 33.87 | mse 14.30 | mre 473162.71 |gepc 15.36 |
# scGPT - INFO - | epoch   1 | 18100/19390 batches | lr 0.0001 | ms/batch 404.60 | loss 33.01 | mse 13.84 | mre 456203.46 |gepc 14.94 |
# scGPT - INFO - | epoch   1 | 18200/19390 batches | lr 0.0001 | ms/batch 404.84 | loss 34.06 | mse 14.36 | mre 470766.24 |gepc 15.50 |
# scGPT - INFO - | epoch   1 | 18300/19390 batches | lr 0.0001 | ms/batch 403.16 | loss 47.00 | mse 18.59 | mre 585430.21 |gepc 21.05 |
# scGPT - INFO - | epoch   1 | 18400/19390 batches | lr 0.0001 | ms/batch 404.37 | loss 49.37 | mse 20.88 | mre 649211.24 |gepc 22.09 |
# scGPT - INFO - | epoch   1 | 18500/19390 batches | lr 0.0001 | ms/batch 404.32 | loss 46.22 | mse 20.08 | mre 637226.03 |gepc 20.78 |
# scGPT - INFO - | epoch   1 | 18600/19390 batches | lr 0.0001 | ms/batch 404.42 | loss 45.11 | mse 19.59 | mre 615615.66 |gepc 20.24 |
# scGPT - INFO - | epoch   1 | 18700/19390 batches | lr 0.0001 | ms/batch 404.36 | loss 44.86 | mse 19.55 | mre 613921.87 |gepc 20.12 |
# scGPT - INFO - | epoch   1 | 18800/19390 batches | lr 0.0001 | ms/batch 404.31 | loss 44.30 | mse 19.32 | mre 609440.34 |gepc 19.90 |
# scGPT - INFO - | epoch   1 | 18900/19390 batches | lr 0.0001 | ms/batch 404.33 | loss 44.05 | mse 19.27 | mre 612708.74 |gepc 19.77 |
# scGPT - INFO - | epoch   1 | 19000/19390 batches | lr 0.0001 | ms/batch 405.16 | loss 43.71 | mse 19.14 | mre 601243.93 |gepc 19.67 |
# scGPT - INFO - | epoch   1 | 19100/19390 batches | lr 0.0001 | ms/batch 404.60 | loss 42.99 | mse 18.81 | mre 596184.75 |gepc 19.32 |
# scGPT - INFO - | epoch   1 | 19200/19390 batches | lr 0.0001 | ms/batch 404.43 | loss 43.57 | mse 19.14 | mre 607172.77 |gepc 19.64 |
# scGPT - INFO - | epoch   1 | 19300/19390 batches | lr 0.0001 | ms/batch 404.46 | loss 43.74 | mse 19.30 | mre 610694.67 |gepc 19.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   1 | time: 8123.24s | valid loss/mse 27.0126 | mre 541753.4032
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 27.0126
# scGPT - INFO - Saving model to save/dev_Breast_HD-May17-00-58
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 21542/21542 [45:46<00:00,  7.84it/s]
# Recompute neighbors on rep X_scGPT instead of None
# Cluster for cluster_0.2 with leiden
# /home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/scib/metrics/clustering.py:96: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   cluster_function(adata, resolution=res, key_added=resolution_key, **kwargs)
# Cluster for cluster_0.4 with leiden
# Cluster for cluster_0.6 with leiden
# Cluster for cluster_0.8 with leiden
# Cluster for cluster_1.0 with leiden
# Cluster for cluster_1.2 with leiden
# Cluster for cluster_1.4 with leiden
# Cluster for cluster_1.6 with leiden
# Cluster for cluster_1.8 with leiden
# Cluster for cluster_2.0 with leiden
# NMI...
# ARI...
# Silhouette score...
# scGPT - ERROR - Input contains NaN
# Traceback (most recent call last):
#   File "/tmp/ipykernel_743345/2112566277.py", line 228, in eval_testdata
#     results = eval_scib_metrics(adata_t)
#   File "/home/whytin/Research/Project/scGPT/tutorials/../scgpt/utils/util.py", line 379, in eval_scib_metrics
#     results = scib.metrics.metrics(
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/scib/metrics/metrics.py", line 328, in metrics
#     asw_label = silhouette(
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/scanpy/_utils/__init__.py", line 185, in wrapper
#     return func(*args, **kwargs)
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/scib/metrics/silhouette.py", line 49, in silhouette
#     asw = silhouette_score(
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/sklearn/metrics/cluster/_unsupervised.py", line 141, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/sklearn/metrics/cluster/_unsupervised.py", line 279, in silhouette_samples
#     X, labels = check_X_y(X, labels, accept_sparse=["csr"])
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1318, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1340, in _check_y
#     _assert_all_finite(y, input_name="y", estimator_name=estimator_name)
#   File "/home/whytin/miniconda3/envs/scgpt310/lib/python3.10/site-packages/sklearn/utils/validation.py", line 108, in _assert_all_finite
#     raise ValueError("Input contains NaN")
# ValueError: Input contains NaN
# wandb: Network error (InvalidSchema), entering retry loop.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 75
#      70     metrics_to_log["test/celltype_umap"] = wandb.Image(
#      71         str(save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png"),
#      72         caption=f"celltype avg_bio epoch {best_model_epoch}",
#      73     )
#      74     metrics_to_log["test/best_model_epoch"] = best_model_epoch
# ---> 75     wandb.log(metrics_to_log)
#      76     wandb.log({"avg_bio": results.get("avg_bio", 0.0)})
#      78 scheduler.step()
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:406, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     403     run_id = self._attach_id
#     405 with wb_logging.log_to_run(run_id):
# --> 406     return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:503, in _noop_if_forked_with_no_service.<locals>.wrapper(self, *args, **kwargs)
#     500 init_pid = self._init_pid
#     502 if is_using_service or init_pid == os.getpid():
# --> 503     return func(self, *args, **kwargs)
#     505 message = (
#     506     f"`{func.__name__}` ignored (called from pid={os.getpid()},"
#     507     f" `init` called from pid={init_pid})."
#     508     f" See: {url_registry.url('multiprocess')}"
#     509 )
#     511 # This attribute may not exist because it is not included in the run's
#     512 # pickled state.
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:464, in _raise_if_finished.<locals>.wrapper_fn(self, *args, **kwargs)
#     461 @functools.wraps(func)
#     462 def wrapper_fn(self: Run, *args, **kwargs) -> _T:
#     463     if not getattr(self, "_is_finished", False):
# --> 464         return func(self, *args, **kwargs)
#     466     message = (
#     467         f"Run ({self.id}) is finished. The call to"
#     468         f" `{func.__name__}` will be ignored."
#     469         f" Please make sure that you are using an active run."
#     470     )
#     472     raise UsageError(message)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:451, in _attach.<locals>.wrapper(self, *args, **kwargs)
#     448     finally:
#     449         _is_attaching = ""
# --> 451 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:2071, in Run.log(self, data, step, commit, sync)
#    2064 if self._settings._shared and step is not None:
#    2065     wandb.termwarn(
#    2066         "In shared mode, the use of `wandb.log` with the step argument is not supported "
#    2067         f"and will be ignored. Please refer to {url_registry.url('define-metric')} "
#    2068         "on how to customize your x-axis.",
#    2069         repeat=False,
#    2070     )
# -> 2071 self._log(data=data, step=step, commit=commit)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:1783, in Run._log(self, data, step, commit)
#    1780 if any(not isinstance(key, str) for key in data.keys()):
#    1781     raise ValueError("Key values passed to `wandb.log` must be strings.")
# -> 1783 self._partial_history_callback(data, step, commit)
#    1785 if step is not None:
#    1786     if os.getpid() != self._init_pid or self._is_attached:
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:406, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     403     run_id = self._attach_id
#     405 with wb_logging.log_to_run(run_id):
# --> 406     return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:1610, in Run._partial_history_callback(self, data, step, commit)
#    1607 data = self._serialize_custom_charts(data)
#    1609 not_using_tensorboard = len(wandb.patched["tensorboard"]) == 0
# -> 1610 self._backend.interface.publish_partial_history(
#    1611     self,
#    1612     data,
#    1613     user_step=self._step,
#    1614     step=step,
#    1615     flush=commit,
#    1616     publish_step=not_using_tensorboard,
#    1617 )
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/interface/interface.py:673, in InterfaceBase.publish_partial_history(self, run, data, user_step, step, flush, publish_step)
#     664 def publish_partial_history(
#     665     self,
#     666     run: "Run",
#    (...)
#     671     publish_step: bool = True,
#     672 ) -> None:
# --> 673     data = history_dict_to_json(run, data, step=user_step, ignore_copy_err=True)
#     674     data.pop("_step", None)
#     676     # add timestamp to the history request, if not already present
#     677     # the timestamp might come from the tensorboard log logic
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/data_types/utils.py:54, in history_dict_to_json(run, payload, step, ignore_copy_err)
#      50         payload[key] = history_dict_to_json(
#      51             run, val, step=step, ignore_copy_err=ignore_copy_err
#      52         )
#      53     else:
# ---> 54         payload[key] = val_to_json(
#      55             run, key, val, namespace=step, ignore_copy_err=ignore_copy_err
#      56         )
#      58 return payload
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/data_types/utils.py:162, in val_to_json(run, key, val, namespace, ignore_copy_err)
#     157         # Partitioned tables and joined tables do not support being bound to runs.
#     158         if not (
#     159             hasattr(val, "_log_type")
#     160             and val._log_type in ["partitioned-table", "joined-table"]
#     161         ):
# --> 162             val.bind_to_run(run, key, namespace)
#     164     return val.to_json(run)
#     166 return converted
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/data_types/image.py:404, in Image.bind_to_run(self, run, key, step, id_, ignore_copy_err)
#     398 if self.path_is_reference(self._path):
#     399     raise ValueError(
#     400         "Image media created by a reference to external storage cannot currently be added to a run"
#     401     )
#     403 if (
# --> 404     not _server_accepts_artifact_path(run)
#     405     or self._get_artifact_entry_ref_url() is None
#     406 ):
#     407     super().bind_to_run(run, key, step, id_, ignore_copy_err=ignore_copy_err)
#     408 if self._boxes is not None:
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/data_types/image.py:58, in _server_accepts_artifact_path(run)
#      55 if run.offline:
#      56     return False
# ---> 58 max_cli_version = util._get_max_cli_version()
#      59 if max_cli_version is None:
#      60     return False
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/util.py:1767, in _get_max_cli_version()
#    1766 def _get_max_cli_version() -> Union[str, None]:
# -> 1767     max_cli_version = wandb.api.max_cli_version()
#    1768     return str(max_cli_version) if max_cli_version is not None else None
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/apis/internal.py:86, in Api.max_cli_version(self)
#      85 def max_cli_version(self):
# ---> 86     return self.api.max_cli_version()
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/apis/normalize.py:25, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      23 message = "Whoa, you found a bug."
#      24 try:
# ---> 25     return func(*args, **kwargs)
#      27 except requests.HTTPError as error:
#      28     errors = parse_backend_error_messages(error.response)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/internal/internal_api.py:979, in Api.max_cli_version(self)
#     976 if self._max_cli_version is not None:
#     977     return self._max_cli_version
# --> 979 query_types, server_info_types, _ = self.server_info_introspection()
#     980 cli_version_exists = (
#     981     "serverInfo" in query_types and "cliVersionInfo" in server_info_types
#     982 )
#     983 if not cli_version_exists:
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/apis/normalize.py:25, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      23 message = "Whoa, you found a bug."
#      24 try:
# ---> 25     return func(*args, **kwargs)
#      27 except requests.HTTPError as error:
#      28     errors = parse_backend_error_messages(error.response)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/internal/internal_api.py:621, in Api.server_info_introspection(self)
#     615 if (
#     616     self.query_types is None
#     617     or self.mutation_types is None
#     618     or self.server_info_types is None
#     619 ):
#     620     query = gql(query_string)
# --> 621     res = self.gql(query)
#     623     self.query_types = [
#     624         field.get("name", "")
#     625         for field in res.get("QueryType", {}).get("fields", [{}])
#     626     ]
#     627     self.mutation_types = [
#     628         field.get("name", "")
#     629         for field in res.get("MutationType", {}).get("fields", [{}])
#     630     ]
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/internal/internal_api.py:370, in Api.gql(self, *args, **kwargs)
#     369 def gql(self, *args: Any, **kwargs: Any) -> Any:
# --> 370     ret = self._retry_gql(
#     371         *args,
#     372         retry_cancel_event=self.context.cancel_event,
#     373         **kwargs,
#     374     )
#     375     return ret
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/retry.py:193, in Retry.__call__(self, *args, **kwargs)
#     186             wandb.termlog(
#     187                 "{} ({}), entering retry loop.".format(
#     188                     self._error_prefix, e.__class__.__name__
#     189                 )
#     190             )
#     191     # if wandb.env.is_debug():
#     192     #     traceback.print_exc()
# --> 193 cancelled = self._sleep_check_cancelled(
#     194     sleep + random.random() * 0.25 * sleep, cancel_event=retry_cancel_event
#     195 )
#     196 if cancelled:
#     197     raise RetryCancelledError("retry timeout")
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/retry.py:89, in Retry._sleep_check_cancelled(self, wait_seconds, cancel_event)
#      87     SLEEP_FN(wait_seconds)
#      88     return False
# ---> 89 cancelled = cancel_event.wait(wait_seconds)
#      90 return cancelled
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
adata
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x775968537640>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7757c63ec5b0, raw_cell="adata" store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://ssh-remote%2B10.6.43.154/home/whytin/Research/Project/scGPT/tutorials/Tutorial_Integration.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:603, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     601 if self.backend.interface is not None:
#     602     self._logger.info("pausing backend")
# --> 603     self.backend.interface.publish_pause()
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/interface/interface.py:770, in InterfaceBase.publish_pause(self)
#     768 def publish_pause(self) -> None:
#     769     pause = pb.PauseRequest()
# --> 770     self._publish_pause(pause)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/interface/interface_shared.py:289, in InterfaceShared._publish_pause(self, pause)
#     287 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     288     rec = self._make_request(pause=pause)
# --> 289     self._publish(rec)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
# AnnData object with n_obs × n_vars = 324669 × 1200
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'S.Score', 'G2M.Score', 'Phase', 'seurat_clusters', 'patient', 'celltype', 'UMAP_1', 'UMAP_2', 'batch', 'batch_id', 'str_batch'
#     var: 'gene_id', 'id_in_vocab', 'gene_name', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'hvg'
#     obsm: 'bin_edges'
#     layers: 'X_normed', 'X_binned'
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x775968537640>> (for post_run_cell), with arguments args (<ExecutionResult object at 7757c63ec6d0, execution_count=19 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7757c63ec5b0, raw_cell="adata" store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://ssh-remote%2B10.6.43.154/home/whytin/Research/Project/scGPT/tutorials/Tutorial_Integration.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D> result=AnnData object with n_obs × n_vars = 324669 × 1200
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'S.Score', 'G2M.Score', 'Phase', 'seurat_clusters', 'patient', 'celltype', 'UMAP_1', 'UMAP_2', 'batch', 'batch_id', 'str_batch'
#     var: 'gene_id', 'id_in_vocab', 'gene_name', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'hvg'
#     obsm: 'bin_edges'
#     layers: 'X_normed', 'X_binned'>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:614, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     611     return
#     613 self._logger.info("resuming backend")
# --> 614 self.backend.interface.publish_resume()
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/interface/interface.py:778, in InterfaceBase.publish_resume(self)
#     776 def publish_resume(self) -> None:
#     777     resume = pb.ResumeRequest()
# --> 778     self._publish_resume(resume)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/interface/interface_shared.py:293, in InterfaceShared._publish_resume(self, resume)
#     291 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     292     rec = self._make_request(resume=resume)
# --> 293     self._publish(rec)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniconda3/envs/scgpt310/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
# save the best model
torch.save(best_model.state_dict(), save_dir / "best_model.pt")

# %%
artifact = wandb.Artifact(f"best_model", type="model")
glob_str = os.path.join(save_dir, "best_model.pt")
artifact.add_file(glob_str)
run.log_artifact(artifact)

run.finish()
wandb.finish()
gc.collect()
# Out:
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_bio</td><td>▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test/best_model_epoch</td><td>▁▃▅▆█</td></tr><tr><td>train/dab</td><td>▂▂▂▂▁▁▁▁▁▂▅▂▁▁▁▁▁▁▂▂▁█▂▁▁▁▁▂▁▁▃▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/ecs</td><td>▆▇▆▅▇▄█▃▄▄▄▅█▅▄▄▃▃▂▄▂▇▃▂▃▃▂▂▃▃▄▃▂▃▂▃▂▁▁▂</td></tr><tr><td>train/mse</td><td>▇▇▆▆▆▆▂▃▂▃▂▅▆▅▃▆▆▂▂▁▃▃█▄▅▃▂▂▂▂▁▁▆▃▅▂▂▂▁▂</td></tr><tr><td>train/mvc</td><td>█▆▆▇▅▃▄▂▂▃▅▅▃▂▂▃▅▅▅▄▂▂▆▇▅▃▂▂▁▂▁▂▂▅▂▃▂▁▁▃</td></tr><tr><td>train/mvc_nzlp</td><td>▅█▄▂▁▁▂▁▃▃▂▁▁▁▃▃▃▁▂▁▁▂▂▄▄▃▂▂▁▁▂▁▁▄▂▃▃▂▁▁</td></tr><tr><td>train/nzlp</td><td>▇▂▂█▄▆▅▆▅▅▂▂▃▂▂▄▃▄▇▅▂▂▆▄▅▄▁▃▃▄▃▁▃▄▅▁▂▁▁▁</td></tr><tr><td>valid/dab</td><td>█▇▆▃▁</td></tr><tr><td>valid/mre</td><td>▆▁█▂▃</td></tr><tr><td>valid/mse</td><td>█▆▅▃▁</td></tr><tr><td>valid/sum_mse_dab</td><td>█▆▅▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_bio</td><td>0</td></tr><tr><td>epoch</td><td>5</td></tr><tr><td>test/best_model_epoch</td><td>5</td></tr><tr><td>train/dab</td><td>7e-05</td></tr><tr><td>train/ecs</td><td>3.64789</td></tr><tr><td>train/mse</td><td>30.5786</td></tr><tr><td>train/mvc</td><td>31.36884</td></tr><tr><td>train/mvc_nzlp</td><td>0.1956</td></tr><tr><td>train/nzlp</td><td>0.17438</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">laced-thunder-11</strong> at: <a href='https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT/runs/3b3ypy6l' target="_blank">https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT/runs/3b3ypy6l</a><br> View project at: <a href='https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT' target="_blank">https://wandb.ai/whytin95-the-university-of-north-carolina-at-chapel-hill/scGPT</a><br>Synced 5 W&B file(s), 10 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250514_015945-3b3ypy6l/logs</code>
# 33893
